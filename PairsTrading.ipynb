# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\chana\anaconda3\lib\site-packages (0.2.18)
# Requirement already satisfied: html5lib>=1.1 in c:\users\chana\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\chana\anaconda3\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\chana\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\chana\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\chana\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\chana\anaconda3\lib\site-packages (from yfinance) (37.0.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\chana\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: requests>=2.26 in c:\users\chana\anaconda3\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\chana\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pytz>=2022.5 in c:\users\chana\anaconda3\lib\site-packages (from yfinance) (2023.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\chana\anaconda3\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\chana\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\chana\anaconda3\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in c:\users\chana\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\chana\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\chana\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\chana\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chana\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chana\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\chana\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.11)
# Requirement already satisfied: pycparser in c:\users\chana\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
btc_data = yf.download('BTC-USD', start='2023-04-11', end='2023-04-12',  interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
btc_data
# Out:
#                                    Open          High           Low  \
# Datetime
# 2023-04-11 00:00:00+00:00  29653.679688  29653.679688  29653.679688
# 2023-04-11 00:01:00+00:00  29672.476562  29672.476562  29672.476562
# 2023-04-11 00:02:00+00:00  29663.371094  29663.371094  29663.371094
# 2023-04-11 00:03:00+00:00  29662.402344  29662.402344  29662.402344
# 2023-04-11 00:04:00+00:00  29651.876953  29651.876953  29651.876953
# ...                                 ...           ...           ...
# 2023-04-11 23:54:00+00:00  30255.207031  30255.207031  30255.207031
# 2023-04-11 23:55:00+00:00  30254.021484  30254.021484  30254.021484
# 2023-04-11 23:56:00+00:00  30241.605469  30241.605469  30241.605469
# 2023-04-11 23:57:00+00:00  30242.962891  30242.962891  30242.962891
# 2023-04-11 23:58:00+00:00  30244.404297  30244.404297  30244.404297
#
#                                   Close     Adj Close   Volume
# Datetime
# 2023-04-11 00:00:00+00:00  29653.679688  29653.679688        0
# 2023-04-11 00:01:00+00:00  29672.476562  29672.476562        0
# 2023-04-11 00:02:00+00:00  29663.371094  29663.371094  1028096
# 2023-04-11 00:03:00+00:00  29662.402344  29662.402344        0
# 2023-04-11 00:04:00+00:00  29651.876953  29651.876953        0
# ...                                 ...           ...      ...
# 2023-04-11 23:54:00+00:00  30255.207031  30255.207031        0
# 2023-04-11 23:55:00+00:00  30254.021484  30254.021484        0
# 2023-04-11 23:56:00+00:00  30241.605469  30241.605469        0
# 2023-04-11 23:57:00+00:00  30242.962891  30242.962891        0
# 2023-04-11 23:58:00+00:00  30244.404297  30244.404297        0
#
# [1315 rows x 6 columns]

# %%
eth_data = yf.download('ETH-USD', start='2023-04-11', end='2023-04-12',  interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
eth_data
# Out:
#                                   Open         High          Low        Close  \
# Datetime
# 2023-04-11 00:00:00+00:00  1911.375854  1911.375854  1911.375854  1911.375854
# 2023-04-11 00:01:00+00:00  1910.985107  1910.985107  1910.985107  1910.985107
# 2023-04-11 00:02:00+00:00  1910.485107  1910.485107  1910.485107  1910.485107
# 2023-04-11 00:03:00+00:00  1910.797852  1910.797852  1910.797852  1910.797852
# 2023-04-11 00:04:00+00:00  1910.106934  1910.106934  1910.106934  1910.106934
# ...                                ...          ...          ...          ...
# 2023-04-11 23:54:00+00:00  1892.502075  1892.502075  1892.502075  1892.502075
# 2023-04-11 23:55:00+00:00  1892.528687  1892.528687  1892.528687  1892.528687
# 2023-04-11 23:56:00+00:00  1891.994141  1891.994141  1891.994141  1891.994141
# 2023-04-11 23:57:00+00:00  1892.116821  1892.116821  1892.116821  1892.116821
# 2023-04-11 23:58:00+00:00  1892.393677  1892.393677  1892.393677  1892.393677
#
#                              Adj Close   Volume
# Datetime
# 2023-04-11 00:00:00+00:00  1911.375854        0
# 2023-04-11 00:01:00+00:00  1910.985107        0
# 2023-04-11 00:02:00+00:00  1910.485107        0
# 2023-04-11 00:03:00+00:00  1910.797852  1628160
# 2023-04-11 00:04:00+00:00  1910.106934  2247680
# ...                                ...      ...
# 2023-04-11 23:54:00+00:00  1892.502075        0
# 2023-04-11 23:55:00+00:00  1892.528687        0
# 2023-04-11 23:56:00+00:00  1891.994141        0
# 2023-04-11 23:57:00+00:00  1892.116821        0
# 2023-04-11 23:58:00+00:00  1892.393677        0
#
# [1315 rows x 6 columns]

# %%
S1_0 = btc_data['Open'][0]
S2_0 = eth_data['Open'][0]

# %%
S1_0
# Out:
# 29653.6796875

# %%
S2_0
# Out:
# 1911.3758544921875

# %%
lr1 = np.log(btc_data['Adj Close'] / btc_data['Adj Close'].shift(1))
lr2 = np.log(eth_data['Adj Close'] / eth_data['Adj Close'].shift(1))
mu_1 = lr1.mean() * 390
mu_2 = lr2.mean() * 390
sigma_1 = lr1.std() * np.sqrt(390)
sigma_2 = lr2.std() * np.sqrt(390)
rho = lr1.corr(lr2)
z_0 = 0.00
gamma = 0.5
delta = 0.8
T = 1
M = len(btc_data)

# %%
result = linregress(np.log(btc_data['Adj Close']), np.log(eth_data['Adj Close']))
beta = result.slope

# %%
dt = T/M
S1 = np.zeros((M + 1, 1))
S2 = np.zeros((M + 1, 1))
z =  np.zeros((M + 1, 1))
a =  np.zeros((M + 1, 1))
b =  np.zeros((M + 1, 1))
c =  np.zeros((M + 1, 1))
Pi_1 = np.zeros((M + 1, 1))
Pi_2 = np.zeros((M + 1, 1))

# %%
tt = np.linspace(0, 1, M + 1)
z[0] = z_0
S1[0] = S1_0
S2[0] = S2_0
sigma_beta = np.sqrt(sigma_1 ** 2 + beta ** 2 * sigma_2 ** 2 + 2 * beta * sigma_1 * sigma_2 * rho)
eta = (-1/delta) * (mu_1 - sigma_1 ** 2/2 + beta*(mu_2 - sigma_2 ** 2/2))
rn = np.random.standard_normal(z.shape)
rn1 = np.random.standard_normal(S1.shape) 
rn2 = np.random.standard_normal(S2.shape) 
for t in range(1, M + 1):
    z[t] = z[t-1]* (1 - delta * (eta - z[t-1])) * dt + sigma_beta * np.sqrt(dt)*((sigma_1 + beta * sigma_2 * rho)/ sigma_beta * rn1[t] + beta * (sigma_2 * np.sqrt(1-rho ** 2)/sigma_beta) * rn1[t]);
    S1[t] = btc_data['Adj Close'][t-1]
    S2[t] = eth_data['Adj Close'][t-1]

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, S1, 'b', lw=1.5, label='Stock 1')
plt.plot(tt, S2, 'r', lw=1.5, label='Stock 2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Stock Price')
# Out:
# Text(0.5, 1.0, 'Stock Price')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, z, 'g', lw=1.5)
plt.xlabel('Time')
plt.ylabel('Rate')
plt.title('z')
# Out:
# Text(0.5, 1.0, 'z')

# %%
for t in range(1, M + 1):
    a[t] = 0.5 * (T - t * dt)/((1-rho ** 2) * sigma_1 ** 2)
    b[t] = - 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2)/((1 - rho ** 2) * sigma_1 ** 2) - rho * mu_2 * (T - t * dt)/((1 - rho **2) * sigma_1 * sigma_2)
    c[t] = 0.5 * mu_2 ** 2 * (T - t * dt)/((1 - rho ** 2) * sigma_2 ** 2) + 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2 + 2 * sigma_1 * sigma_2 * beta *rho) * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2) + 0.25 * (T - t * dt) ** 2 * mu_2 * delta * rho * (sigma_1 ** 2 + beta * sigma_2 ** 2) + 1/24 * (T - t * dt) ** 3 * (sigma_1 ** 2 + beta * sigma_2 ** 2) ** 2 * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2)
    Pi_1[t] = (1 / S1[t]) * ((mu_1 + delta * z[t])/(gamma * (1 - rho ** 2) * sigma_1 ** 2) + delta/gamma * (-2 * a[t] * (mu_1 + delta * z[t])-b[t]) - rho * mu_2/(gamma * (1 - rho ** 2) * sigma_1 * sigma_2))
    Pi_2[t] = (1 / S2[t]) * (mu_2 / (gamma * (1 - rho ** 2) * sigma_2 ** 2) + delta * beta / gamma * (- 2 * a[t] * (mu_1 + delta * z[t]) - b[t]) - rho * (mu_1 + delta * z[t]) / (gamma * (1 - rho ** 2) * sigma_1 * sigma_2))

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1, 'b', lw=1.5, label='w1')
plt.plot(tt, Pi_2, 'r', lw=1.5, label='w2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('%')
plt.title('Weights')
# Out:
# Text(0.5, 1.0, 'Weights')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1, 'b', lw=1.5, label='Wealth 1')
plt.plot(tt, Pi_2 * S2, 'r', lw=1.5, label='Wealth 2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Cash')
# Out:
# Text(0.5, 1.0, 'Cash')

# %%
Wealth = abs(Pi_1 * S1) + abs(Pi_2 * S2)

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt[1:], Wealth[1:], 'b', lw=1.5, label='Total')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Wealth')
# Out:
# Text(0.5, 1.0, 'Wealth')

# %%
Wealth[1]
# Out:
# array([477.39134144])

# %%
Wealth[-1]
# Out:
# array([922.56198017])

# %%
(Wealth[-1] - Wealth[1])/Wealth[1]
# Out:
# array([0.93250673])
